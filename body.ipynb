# %%
import cv2
import dlib

# %%
input3=cv2.imread('drive/MyDrive/Face detection/task1/people3.jpg')
input3
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
gray_image=cv2.cvtColor(input3,cv2.COLOR_BGR2GRAY)
gray_image
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
body_model=cv2.CascadeClassifier('drive/MyDrive/Face detection/task1/fullbody.xml')

# %%
bodys=body_model.detectMultiScale(gray_image,scaleFactor=1.005, minNeighbors=3)

# %%
bodys
# Out:
# array([[462,  63,  88, 176],
#        [ 74,  76,  86, 172],
#        [267,  85,  73, 147],
#        [197,  52,  93, 186],
#        [140,  82,  79, 157],
#        [390,  47,  98, 196],
#        [ 15,  65,  79, 158],
#        [325,  70,  84, 168],
#        [537, 126,  55, 110],
#        [429, 164,  35,  70]], dtype=int32)

# %%
import numpy as np
for (i, rect) in enumerate(bodys):
    x,y,w,h=rect
    #draw a rectangle
    cv2.rectangle(input, (x, y), (x + w, y + h), (0, 0, 255), 2)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(input)
# Out:
# <PIL.Image.Image image mode=RGB size=626x294>
